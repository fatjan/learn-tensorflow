# %% [markdown]
# <a href="https://colab.research.google.com/github/fatjan/learn-tensorflow/blob/master/Hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.0.0-alpha0
# Out:
# ...
#      |████████████████████████████████| 79.9MB 52kB/s
# ...
#      |████████████████████████████████| 3.0MB 47.3MB/s
# ...
#      |████████████████████████████████| 419kB 31.3MB/s
# ...
#   Found existing installation: tensorflow 2.2.0
#     Uninstalling tensorflow-2.2.0:
#       Successfully uninstalled tensorflow-2.2.0
# ...

# %%
from tensorflow import keras
import numpy as np

# %%
# this is a model with one layer, and 1 input, 1D
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')
# sgd : stochastic gradient descent

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 0s 8ms/sample - loss: 43.3280
# Epoch 2/500
# 6/6 [==============================] - 0s 611us/sample - loss: 42.3933
# Epoch 3/500
# 6/6 [==============================] - 0s 512us/sample - loss: 41.4794
# Epoch 4/500
# 6/6 [==============================] - 0s 482us/sample - loss: 40.5861
# Epoch 5/500
# 6/6 [==============================] - 0s 465us/sample - loss: 39.7127
# Epoch 6/500
# 6/6 [==============================] - 0s 914us/sample - loss: 38.8588
# Epoch 7/500
# 6/6 [==============================] - 0s 672us/sample - loss: 38.0241
# Epoch 8/500
# 6/6 [==============================] - 0s 494us/sample - loss: 37.2081
# Epoch 9/500
# 6/6 [==============================] - 0s 475us/sample - loss: 36.4103
# Epoch 10/500
# 6/6 [==============================] - 0s 468us/sample - loss: 35.6304
# Epoch 11/500
# 6/6 [==============================] - 0s 464us/sample - loss: 34.8679
# Epoch 12/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[16.478134]]

# %%
print(model.predict([20.0]))
# Out:
# [[32.8666]]

# %%
print(model.predict([105.0, 209.0]))
# Out:
# [[172.16855]
#  [342.60858]]
